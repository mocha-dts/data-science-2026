# %% [markdown]
# <a href="https://colab.research.google.com/github/mocha-dts/data-science-2026/blob/main/Pertemuan2_MochamadRochmatullah_240401010041.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Memuat dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"
df = pd.read_csv(url)
df[['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Q1. Berapa jumlah baris dan kolom pada dataset Titanic? Kolom apa saja yang tersedia?

print(df.shape, df.columns.tolist())
# Out:
# (891, 12) ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
# Q2. Kolom mana saja yang memiliki missing values? Berapa jumlah dan proporsinya (%) per kolom?

missing_count = df.isnull().sum()
missing_percent = (missing_count / len(df)) * 100
missing_summary = pd.DataFrame({
    'Jumlah Missing': missing_count,
    'Proporsi (%)': missing_percent
})
missing_summary = missing_summary[missing_summary['Jumlah Missing'] > 0]
missing_summary = missing_summary.sort_values(by='Jumlah Missing', ascending=False)
print(missing_summary)
# Out:
#           Jumlah Missing  Proporsi (%)
# Cabin                687     77.104377
# Age                  177     19.865320
# Embarked               2      0.224467

# %%
# Q3. Berapa persen penumpang yang selamat (Survived=1)? Gunakan operasi NumPy atau Pandas.

survival_rate = df['Survived'].mean() * 100
print(f"Persentase penumpang yang selamat: {survival_rate:.2f}%")
# Out:
# Persentase penumpang yang selamat: 38.38%

# %%
# Q4. Filter penumpang wanita dari kelas 1 (Pclass=1). Berapa jumlahnya dan berapa rata-rata usianya?

female_class1 = df[(df['Sex'] == 'female') & (df['Pclass'] == 1)]
jumlah = len(female_class1)
rata_usia = female_class1['Age'].mean()
print(f"Jumlah penumpang wanita kelas 1: {jumlah}")
print(f"Rata-rata usia: {rata_usia:.2f} tahun")
# Out:
# Jumlah penumpang wanita kelas 1: 94
# Rata-rata usia: 34.61 tahun

# %%
# Q5. Gunakan groupby untuk menghitung tingkat keselamatan (mean Survived) per kelas penumpang. Kelas mana yang paling tinggi?

survival_by_class = df.groupby('Pclass')['Survived'].mean()
print(survival_by_class)
print(f"Kelas 1 (Pclass = 1) memiliki tingkat keselamatan paling tinggi")
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64
# Kelas 1 (Pclass = 1) memiliki tingkat keselamatan paling tinggi

# %%
# Q6. Buat analisis tambahan berdasarkan variabel lain yang Anda anggap menarik. Sertakan interpretasi singkat.

survival_by_gender = df.groupby('Sex')['Survived'].mean()
print(survival_by_gender)
print(f"Perempuan memiliki peluang selamat jauh lebih tinggi. Ini konsisten dengan prinsip evakuasi “women and children first” saat tragedi RMS Titanic sinking.")

survival_gender_class = df.groupby(['Sex', 'Pclass'])['Survived'].mean()
print(survival_gender_class)
print(f"Faktor gender dan kelas saling berinteraksi. Wanita tetap lebih diutamakan, tetapi kelas sosial masih sangat berpengaruh (akses evakuasi berbeda)")

df['Category_Age'] = df['Age'].apply(lambda x: 'Child' if x < 18 else 'Adult')
survival_by_age = df.groupby('Category_Age')['Survived'].mean()
print(survival_by_age)
print(f"Anak-anak punya peluang lebih tinggi untuk selamat dikarenakan menjadi prioritas evakuasi.")

survival_by_embarked = df.groupby('Embarked')['Survived'].mean()
print(survival_by_embarked)
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64
# Perempuan memiliki peluang selamat jauh lebih tinggi. Ini konsisten dengan prinsip evakuasi “women and children first” saat tragedi RMS Titanic sinking.
# Sex     Pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: Survived, dtype: float64
# Faktor gender dan kelas saling berinteraksi. Wanita tetap lebih diutamakan, tetapi kelas sosial masih sangat berpengaruh (akses evakuasi berbeda)
# Category_Age
# Adult    0.361183
# Child    0.539823
# Name: Survived, dtype: float64
# Anak-anak punya peluang lebih tinggi untuk selamat dikarenakan menjadi prioritas evakuasi.
# Embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: Survived, dtype: float64
